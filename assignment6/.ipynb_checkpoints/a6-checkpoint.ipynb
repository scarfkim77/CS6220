# %% [markdown]
# Step 1 Split the dataset into training and test sets (80, 20).

# %%
from sklearn.datasets import load_boston
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

boston = load_boston()
x_data = boston.data
y_data = boston.target
name_data = boston.feature_names

x_train, x_test, y_train, y_test = train_test_split(x_data, y_data, test_size=0.2)

# %% [markdown]
# Step 2(a) Use all the features (1-13) to fit the linear regression model for feature 14 using the training set.

# %%
regr=LinearRegression()
regr.fit(x_train,y_train)
y_pred=regr.predict(x_test)

# %% [markdown]
# Step 2(b) Report the coefficients, mean squared error and variance score for the model on the test set.

# %%
# The coefficients
print('Coefficients:', regr.coef_)
# The mean squared error
print("Mean squared error: %.2f" % np.mean((y_pred - y_test)**2))
# Explained variance score : 1 is perfect prediction
print('Variance score: %.2f' % regr.score(x_test , y_test))
# Out:
# Coefficients: [-1.09521492e-01  4.82976174e-02  2.52090352e-02  2.37384568e+00
#  -2.03292366e+01  3.49567077e+00 -4.79835307e-03 -1.59159561e+00
#   3.71458732e-01 -1.42997473e-02 -9.77321275e-01  9.34754599e-03
#  -5.54726980e-01]
# Mean squared error: 16.53
# Variance score: 0.73

# %% [markdown]
# Step 3(a) and Step 3(b)

# %%
plt.figure(figsize=(10,10))
for i in range(13):
    plt.subplot(4, 4, i + 1)
    x=pd.DataFrame(boston.data[:,i])
    x_train, x_test, y_train, y_test = train_test_split(x, y_data, test_size=0.2)
    lr = LinearRegression()
    lr.fit(x_train, y_train)
    y_pre =lr.predict(x_test)
    plt.scatter(x_train, y_train, label='train')
    plt.scatter(x_test, y_test, label='test')
    plt.plot(x_test.values.reshape(-1,1) , y_pre,label='line')
    print('for fit on feature:'+boston.feature_names[i])
    # The coefficients
    print('Coefficients:', lr.coef_)
    # The mean squared error
    print("Mean squared error: %.2f" % (np.sum((y_pre-y_test)**2)/len(y_test)))
    # Explained variance score : 1 is perfect prediction
    print('Variance score: %.2f' % lr.score(x_test,y_test))
plt.show()
# Out:
# for fit on feature:CRIM
# Coefficients: [-0.45409474]
# Mean squared error: 94.90
# Variance score: 0.07
# for fit on feature:ZN
# Coefficients: [0.12998172]
# Mean squared error: 80.70
# Variance score: 0.19
# for fit on feature:INDUS
# Coefficients: [-0.64886721]
# Mean squared error: 75.61
# Variance score: 0.22
# for fit on feature:CHAS
# Coefficients: [5.53256079]
# Mean squared error: 90.88
# Variance score: 0.04
# for fit on feature:NOX
# Coefficients: [-32.57054347]
# Mean squared error: 74.65
# Variance score: 0.21
# for fit on feature:RM
# Coefficients: [9.1592149]
# Mean squared error: 50.75
# Variance score: 0.47
# for fit on feature:AGE
# Coefficients: [-0.13447624]
# Mean squared error: 78.90
# Variance score: 0.03
# for fit on feature:DIS
# Coefficients: [1.0883143]
# Mean squared error: 88.65
# Variance score: 0.04
# for fit on feature:RAD
# Coefficients: [-0.40720909]
# Mean squared error: 62.09
# Variance score: 0.15
# for fit on feature:TAX
# ...

# %% [markdown]
# Step 4(a) and Step 4(b)

# %%
coef_temp=[]
mse_all=[]
vs_all=[]
coef_feas = []
mse_feas = []
vs_feas = []
for j in range(10):
    x_train, x_test, y_train, y_test = train_test_split(x_data, y_data, test_size=0.2)
    regr=LinearRegression()
    regr.fit(x_train,y_train)
    y_predict=regr.predict(x_test)
    # The coefficients
    coef_temp.append(regr.coef_)
    # The mean squared error
    mse_all.append((np.sum((y_predict-y_test)**2)/len(y_test)))
    # Explained variance score : 1 is perfect prediction
    vs_all.append(regr.score(x_test,y_test))
for m in range(10):
    temp1 = []
    temp2 = []
    temp3 = []
    for i in range(13):
        x=pd.DataFrame(boston.data[:,i])
        x_train, x_test, y_train, y_test = train_test_split(x, y_data, test_size=0.2)
        lr = LinearRegression()
        lr.fit(x_train, y_train)
        y_pre =lr.predict(x_test)
        # The coefficients
        temp1.append(lr.coef_)
        # The mean squared error
        temp2.append((np.sum((y_pre-y_test)**2)/len(y_test)))
        # Explained variance score : 1 is perfect prediction
        temp3.append(lr.score(x_test,y_test))
    coef_feas.append(temp1)
    mse_feas.append(temp2)
    vs_feas.append(temp3)
coef_all=[]
coef=[]
mse=[]
vs=[]
for n in range(13):
    temp_all=0
    temp=0
    temp_mse=0
    temp_vs=0
    for a in range(10):
        temp_all+=coef_temp[a][n]
        temp += coef_feas[a][n]
        temp_mse+=mse_feas[a][n]
        temp_vs+=vs_feas[a][n]
    temp_all=temp_all/10
    temp=temp/10
    temp_mse=temp_mse/10
    temp_vs=temp_vs/10
    coef_all.append(temp_all)
    coef.append(temp)
    mse.append(temp_mse)
    vs.append(temp_vs)
    print('for feature:' + boston.feature_names[n])
    print("Averange of coefficients: %.2f" % temp[0])
    print("Averange of mean squared error: %.2f" % mse[n])
    print("Averange of variance score: %.2f" % vs[n])

print("for all features:")
print("Averange of coefficients:",coef_all)
print("Averange of mean squared error:%.2f" % (sum(mse_all) / len(mse_all)))
print("Averange of variance score:%.2f" % (sum(vs_all) / len(vs_all)))

plt.figure()
name_data=name_data.tolist()
name_data.append("all features")
mse.append((sum(mse_all) / len(mse_all)))
vs.append((sum(vs_all) / len(vs_all)))
plt.subplot(2,1,1)
s1=plt.scatter(name_data,mse)
plt.ylabel('mean squared error')
plt.subplot(2,1,2)
s2=plt.scatter(name_data,vs)
plt.ylabel('variance score')
plt.xlabel('features')
plt.show()
# Out:
# for feature:CRIM
# Averange of coefficients: -0.43
# Averange of mean squared error: 79.71
# Averange of variance score: 0.13
# for feature:ZN
# Averange of coefficients: 0.14
# Averange of mean squared error: 75.35
# Averange of variance score: 0.11
# for feature:INDUS
# Averange of coefficients: -0.65
# Averange of mean squared error: 64.11
# Averange of variance score: 0.23
# for feature:CHAS
# Averange of coefficients: 6.60
# Averange of mean squared error: 86.04
# Averange of variance score: 0.00
# for feature:NOX
# Averange of coefficients: -34.54
# Averange of mean squared error: 63.00
# Averange of variance score: 0.16
# for feature:RM
# Averange of coefficients: 8.98
# Averange of mean squared error: 42.02
# Averange of variance score: 0.51
# for feature:AGE
# Averange of coefficients: -0.12
# Averange of mean squared error: 75.59
# Averange of variance score: 0.12
# for feature:DIS
# Averange of coefficients: 1.12
# Averange of mean squared error: 74.98
# ...

# %% [markdown]
# 1. Based upon the linear models you generated, which feature appears to be most predictive for the target feature? Note that you can answer this question based upon the output provided for the linear models.

# %% [markdown]
#     Based upon the linear models above, RM and LSTAT are most predictive for the target feature. They have low averange of mean squared error and high averange of variance score.

# %% [markdown]
# 2. Suppose you need to select two features for a linear regression model to predict the target feature. Which two features would you select? Why?

# %% [markdown]
#     I would select RM and LSTAT to predict the target feature. Based upon the output above, they have more obvious linear relationship with the data set.

# %% [markdown]
# 3. Examine all the plots and numbers you have, do you have any comments on them? Do you find any surprising trends? Do you have any idea about what might be causing this surprising trend in the data? This is a descriptive question meant to encourage you to interpret your results and express yourself.

# %% [markdown]
#     Actually, when we are applying all the 13 features for the target feature, the result is most predictive. But there are also some features having little influence on the prediction effect, like CHAS and RAD. The possible reason could be that they have extreme data distribution and don't show obvious linear relationship.
